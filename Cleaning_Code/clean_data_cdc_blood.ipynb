# %%
# %load_ext lab_black
import pandas as pd

# %%
file_to_load = (
    "../Data/500_Cities__High_blood_pressure_among_adults_aged___18_years.csv"
)

df = pd.read_csv(file_to_load)
df.head()
# Out:
#    Year StateAbbr StateDesc  CityName GeographicLevel DataSource  \
# 0  2017        IL  Illinois     Elgin    Census Tract      BRFSS
# 1  2017        IL  Illinois    Joliet    Census Tract      BRFSS
# 2  2017        IL  Illinois    Peoria    Census Tract      BRFSS
# 3  2017        IL  Illinois  Rockford    Census Tract      BRFSS
# 4  2017        IL  Illinois    Cicero            City      BRFSS
#
#           Category             UniqueID  \
# 0  Health Outcomes  1723074-17089850800
# 1  Health Outcomes  1738570-17197882601
# 2  Health Outcomes  1759000-17143002600
# 3  Health Outcomes  1765000-17201000510
# 4  Health Outcomes              1714351
#
#                                             Measure Data_Value_Unit  ...  \
# 0  High blood pressure among adults aged >=18 Years               %  ...
# 1  High blood pressure among adults aged >=18 Years               %  ...
# 2  High blood pressure among adults aged >=18 Years               %  ...
# 3  High blood pressure among adults aged >=18 Years               %  ...
# 4  High blood pressure among adults aged >=18 Years               %  ...
#
#   High_Confidence_Limit Data_Value_Footnote_Symbol  Data_Value_Footnote  \
# 0                  28.9                        NaN                  NaN
# 1                  36.5                        NaN                  NaN
# 2                  35.7                        NaN                  NaN
# 3                  33.2                        NaN                  NaN
# 4                  32.0                        NaN                  NaN
#
#    PopulationCount                      GeoLocation CategoryID MeasureId  \
# 0             7184  (42.0551091254, -88.2731842934)    HLTHOUT    BPHIGH
# 1             3087  (41.5169533744, -88.1081697049)    HLTHOUT    BPHIGH
# 2             1835  (40.7292949177, -89.5623864579)    HLTHOUT    BPHIGH
# 3             3329  (42.3078216445, -88.9896222053)    HLTHOUT    BPHIGH
# 4            83891   (41.844539143, -87.7592873023)    HLTHOUT    BPHIGH
#
#     CityFIPS     TractFIPS  Short_Question_Text
# 0  1723074.0  1.708985e+10  High Blood Pressure
# 1  1738570.0  1.719788e+10  High Blood Pressure
# 2  1759000.0  1.714300e+10  High Blood Pressure
# 3  1765000.0  1.720100e+10  High Blood Pressure
# 4  1714351.0           NaN  High Blood Pressure
#
# [5 rows x 24 columns]

# %%
df_austin = df[df["CityName"] == "Austin"]
df_austin.reset_index().head()
# Out:
#    index  Year StateAbbr StateDesc CityName GeographicLevel DataSource  \
# 0  25507  2017        TX     Texas   Austin            City      BRFSS
# 1  27368  2017        TX     Texas   Austin    Census Tract      BRFSS
# 2  27374  2017        TX     Texas   Austin    Census Tract      BRFSS
# 3  27378  2017        TX     Texas   Austin    Census Tract      BRFSS
# 4  27379  2017        TX     Texas   Austin    Census Tract      BRFSS
#
#           Category             UniqueID  \
# 0  Health Outcomes              4805000
# 1  Health Outcomes  4805000-48453000604
# 2  Health Outcomes  4805000-48453002113
# 3  Health Outcomes  4805000-48453001718
# 4  Health Outcomes  4805000-48453001908
#
#                                             Measure  ...  \
# 0  High blood pressure among adults aged >=18 Years  ...
# 1  High blood pressure among adults aged >=18 Years  ...
# 2  High blood pressure among adults aged >=18 Years  ...
# 3  High blood pressure among adults aged >=18 Years  ...
# 4  High blood pressure among adults aged >=18 Years  ...
#
#   High_Confidence_Limit Data_Value_Footnote_Symbol Data_Value_Footnote  \
# 0                  22.6                        NaN                 NaN
# 1                  12.8                        NaN                 NaN
# 2                  32.0                        NaN                 NaN
# 3                  23.8                        NaN                 NaN
# 4                  19.0                        NaN                 NaN
#
#    PopulationCount                      GeoLocation  CategoryID MeasureId  \
# 0           790390  (30.3068610342, -97.7554771245)     HLTHOUT    BPHIGH
# 1             6496  (30.2855339039, -97.7477273854)     HLTHOUT    BPHIGH
# 2             3571  (30.3170432569, -97.6725319322)     HLTHOUT    BPHIGH
# 3             5442  (30.3483038697, -97.7610247766)     HLTHOUT    BPHIGH
# 4             5177  (30.2673616151, -97.8917527564)     HLTHOUT    BPHIGH
#
#     CityFIPS     TractFIPS  Short_Question_Text
# 0  4805000.0           NaN  High Blood Pressure
# 1  4805000.0  4.845300e+10  High Blood Pressure
# 2  4805000.0  4.845300e+10  High Blood Pressure
# 3  4805000.0  4.845300e+10  High Blood Pressure
# 4  4805000.0  4.845300e+10  High Blood Pressure
#
# [5 rows x 25 columns]

# %%
df_austin = df_austin.drop(
    columns=[
        "DataSource",
        "Data_Value_Footnote_Symbol",
        "Data_Value_Footnote",
        "CategoryID",
        "Short_Question_Text",
        "Data_Value_Unit",
        "DataValueTypeID",
        "Data_Value_Type",
        "Low_Confidence_Limit",
        "High_Confidence_Limit",
        "CityFIPS",
        "PopulationCount",
    ]
)

# %%
df_austin = df_austin[df_austin["GeographicLevel"] == "Census Tract"]
df_austin["TractFIPS"] = df_austin["TractFIPS"].astype("int").round()

# %%
df_austin[["Lat", "Lng"]] = df_austin.GeoLocation.apply(
    lambda x: pd.Series(str(x).split(","))
)
df_austin
# Out:
#        Year StateAbbr StateDesc CityName GeographicLevel         Category  \
# 27368  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 27374  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 27378  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 27379  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 27380  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# ...     ...       ...       ...      ...             ...              ...
# 28616  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 28642  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 28648  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 28658  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 28687  2017        TX     Texas   Austin    Census Tract  Health Outcomes
#
#                   UniqueID                                           Measure  \
# 27368  4805000-48453000604  High blood pressure among adults aged >=18 Years
# 27374  4805000-48453002113  High blood pressure among adults aged >=18 Years
# 27378  4805000-48453001718  High blood pressure among adults aged >=18 Years
# 27379  4805000-48453001908  High blood pressure among adults aged >=18 Years
# 27380  4805000-48453002212  High blood pressure among adults aged >=18 Years
# ...                    ...                                               ...
# 28616  4805000-48453002426  High blood pressure among adults aged >=18 Years
# 28642  4805000-48491020510  High blood pressure among adults aged >=18 Years
# 28648  4805000-48491020316  High blood pressure among adults aged >=18 Years
# 28658  4805000-48453002422  High blood pressure among adults aged >=18 Years
# 28687  4805000-48453002433  High blood pressure among adults aged >=18 Years
#
#        Data_Value                      GeoLocation MeasureId    TractFIPS  \
# 27368        11.8  (30.2855339039, -97.7477273854)    BPHIGH  48453000604
# 27374        31.0  (30.3170432569, -97.6725319322)    BPHIGH  48453002113
# 27378        22.9  (30.3483038697, -97.7610247766)    BPHIGH  48453001718
# 27379        18.1  (30.2673616151, -97.8917527564)    BPHIGH  48453001908
# 27380        25.5  (30.3101329564, -97.5916015422)    BPHIGH  48453002212
# ...           ...                              ...       ...          ...
# 28616        20.3  (30.1548242628, -97.7520686441)    BPHIGH  48453002426
# 28642        24.5  (30.4935333283, -97.7625330584)    BPHIGH  48491020510
# 28648         NaN  (30.4767287286, -97.8094310538)    BPHIGH  48491020316
# 28658        22.7  (30.1834376979, -97.7848162066)    BPHIGH  48453002422
# 28687        23.7  (30.1912019968, -97.6172300469)    BPHIGH  48453002433
#
#                   Lat               Lng
# 27368  (30.2855339039   -97.7477273854)
# 27374  (30.3170432569   -97.6725319322)
# 27378  (30.3483038697   -97.7610247766)
# 27379  (30.2673616151   -97.8917527564)
# 27380  (30.3101329564   -97.5916015422)
# ...               ...               ...
# 28616  (30.1548242628   -97.7520686441)
# 28642  (30.4935333283   -97.7625330584)
# 28648  (30.4767287286   -97.8094310538)
# 28658  (30.1834376979   -97.7848162066)
# 28687  (30.1912019968   -97.6172300469)
#
# [205 rows x 14 columns]

# %%
df_austin[["Lat"]] = df_austin.Lat.apply(lambda x: pd.Series(x[1:]))
df_austin[["Lng"]] = df_austin.Lng.apply(lambda x: pd.Series(x[:-1]))

df_austin.to_csv("../Data/cleaned_blood_pressure_cdc.csv", index=False)
df_austin
# Out:
#        Year StateAbbr StateDesc CityName GeographicLevel         Category  \
# 27368  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 27374  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 27378  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 27379  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 27380  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# ...     ...       ...       ...      ...             ...              ...
# 28616  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 28642  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 28648  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 28658  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 28687  2017        TX     Texas   Austin    Census Tract  Health Outcomes
#
#                   UniqueID                                           Measure  \
# 27368  4805000-48453000604  High blood pressure among adults aged >=18 Years
# 27374  4805000-48453002113  High blood pressure among adults aged >=18 Years
# 27378  4805000-48453001718  High blood pressure among adults aged >=18 Years
# 27379  4805000-48453001908  High blood pressure among adults aged >=18 Years
# 27380  4805000-48453002212  High blood pressure among adults aged >=18 Years
# ...                    ...                                               ...
# 28616  4805000-48453002426  High blood pressure among adults aged >=18 Years
# 28642  4805000-48491020510  High blood pressure among adults aged >=18 Years
# 28648  4805000-48491020316  High blood pressure among adults aged >=18 Years
# 28658  4805000-48453002422  High blood pressure among adults aged >=18 Years
# 28687  4805000-48453002433  High blood pressure among adults aged >=18 Years
#
#        Data_Value                      GeoLocation MeasureId    TractFIPS  \
# 27368        11.8  (30.2855339039, -97.7477273854)    BPHIGH  48453000604
# 27374        31.0  (30.3170432569, -97.6725319322)    BPHIGH  48453002113
# 27378        22.9  (30.3483038697, -97.7610247766)    BPHIGH  48453001718
# 27379        18.1  (30.2673616151, -97.8917527564)    BPHIGH  48453001908
# 27380        25.5  (30.3101329564, -97.5916015422)    BPHIGH  48453002212
# ...           ...                              ...       ...          ...
# 28616        20.3  (30.1548242628, -97.7520686441)    BPHIGH  48453002426
# 28642        24.5  (30.4935333283, -97.7625330584)    BPHIGH  48491020510
# 28648         NaN  (30.4767287286, -97.8094310538)    BPHIGH  48491020316
# 28658        22.7  (30.1834376979, -97.7848162066)    BPHIGH  48453002422
# 28687        23.7  (30.1912019968, -97.6172300469)    BPHIGH  48453002433
#
#                  Lat              Lng
# 27368  30.2855339039   -97.7477273854
# 27374  30.3170432569   -97.6725319322
# 27378  30.3483038697   -97.7610247766
# 27379  30.2673616151   -97.8917527564
# 27380  30.3101329564   -97.5916015422
# ...              ...              ...
# 28616  30.1548242628   -97.7520686441
# 28642  30.4935333283   -97.7625330584
# 28648  30.4767287286   -97.8094310538
# 28658  30.1834376979   -97.7848162066
# 28687  30.1912019968   -97.6172300469
#
# [205 rows x 14 columns]
