# %%
# %load_ext lab_black
import pandas as pd

# %%
file_to_load = "../Data/500_Cities__High_cholesterol_among_adults_aged___18_years.csv"

df = pd.read_csv(file_to_load)
df.head()
# Out:
#    Year StateAbbr StateDesc       CityName GeographicLevel DataSource  \
# 0  2017        HI    Hawaii       Honolulu    Census Tract      BRFSS
# 1  2017        GA   Georgia       Savannah    Census Tract      BRFSS
# 2  2017        GA   Georgia        Augusta    Census Tract      BRFSS
# 3  2017        ID     Idaho     Boise City    Census Tract      BRFSS
# 4  2017        GA   Georgia  Sandy Springs    Census Tract      BRFSS
#
#           Category             UniqueID  \
# 0  Health Outcomes          15003009802
# 1  Health Outcomes  1369000-13051002100
# 2  Health Outcomes  1304204-13245000100
# 3  Health Outcomes  1608830-16001000201
# 4  Health Outcomes  1368516-13121010212
#
#                                              Measure Data_Value_Unit  ...  \
# 0  High cholesterol among adults aged >=18 Years ...               %  ...
# 1  High cholesterol among adults aged >=18 Years ...               %  ...
# 2  High cholesterol among adults aged >=18 Years ...               %  ...
# 3  High cholesterol among adults aged >=18 Years ...               %  ...
# 4  High cholesterol among adults aged >=18 Years ...               %  ...
#
#   High_Confidence_Limit Data_Value_Footnote_Symbol  Data_Value_Footnote  \
# 0                  34.8                        NaN                  NaN
# 1                  32.1                        NaN                  NaN
# 2                  38.9                        NaN                  NaN
# 3                  31.6                        NaN                  NaN
# 4                  28.4                        NaN                  NaN
#
#    PopulationCount                      GeoLocation CategoryID MeasureId  \
# 0             6386  (21.4678190627, -158.209541749)    HLTHOUT  HIGHCHOL
# 1             2408  (32.0585060267, -81.0807397501)    HLTHOUT  HIGHCHOL
# 2             3753  (33.4861010813, -82.0215987012)    HLTHOUT  HIGHCHOL
# 3             2830   (43.630800932, -116.184507528)    HLTHOUT  HIGHCHOL
# 4             5440  (33.9014010067, -84.3869905014)    HLTHOUT  HIGHCHOL
#
#     CityFIPS     TractFIPS Short_Question_Text
# 0    15003.0  1.500301e+10    High Cholesterol
# 1  1369000.0  1.305100e+10    High Cholesterol
# 2  1304204.0  1.324500e+10    High Cholesterol
# 3  1608830.0  1.600100e+10    High Cholesterol
# 4  1368516.0  1.312101e+10    High Cholesterol
#
# [5 rows x 24 columns]

# %%
df_austin = df[df["CityName"] == "Austin"]
df_austin.reset_index().head()
# Out:
#    index  Year StateAbbr StateDesc CityName GeographicLevel DataSource  \
# 0  24158  2017        TX     Texas   Austin    Census Tract      BRFSS
# 1  24160  2017        TX     Texas   Austin    Census Tract      BRFSS
# 2  24161  2017        TX     Texas   Austin    Census Tract      BRFSS
# 3  24162  2017        TX     Texas   Austin    Census Tract      BRFSS
# 4  24163  2017        TX     Texas   Austin    Census Tract      BRFSS
#
#           Category             UniqueID  \
# 0  Health Outcomes  4805000-48453001842
# 1  Health Outcomes  4805000-48453001501
# 2  Health Outcomes  4805000-48453002425
# 3  Health Outcomes  4805000-48453001754
# 4  Health Outcomes  4805000-48453002402
#
#                                              Measure  ...  \
# 0  High cholesterol among adults aged >=18 Years ...  ...
# 1  High cholesterol among adults aged >=18 Years ...  ...
# 2  High cholesterol among adults aged >=18 Years ...  ...
# 3  High cholesterol among adults aged >=18 Years ...  ...
# 4  High cholesterol among adults aged >=18 Years ...  ...
#
#   High_Confidence_Limit Data_Value_Footnote_Symbol Data_Value_Footnote  \
# 0                  25.6                        NaN                 NaN
# 1                  33.6                        NaN                 NaN
# 2                  25.0                        NaN                 NaN
# 3                  30.9                        NaN                 NaN
# 4                  26.7                        NaN                 NaN
#
#    PopulationCount                      GeoLocation  CategoryID MeasureId  \
# 0             2035  (30.3755684675, -97.6313378757)     HLTHOUT  HIGHCHOL
# 1             4787  (30.3465767365, -97.7433025334)     HLTHOUT  HIGHCHOL
# 2             2798   (30.157617531, -97.7842795909)     HLTHOUT  HIGHCHOL
# 3             4599  (30.4065557514, -97.7373059981)     HLTHOUT  HIGHCHOL
# 4             7082  (30.2016967544, -97.7751694038)     HLTHOUT  HIGHCHOL
#
#     CityFIPS     TractFIPS Short_Question_Text
# 0  4805000.0  4.845300e+10    High Cholesterol
# 1  4805000.0  4.845300e+10    High Cholesterol
# 2  4805000.0  4.845300e+10    High Cholesterol
# 3  4805000.0  4.845300e+10    High Cholesterol
# 4  4805000.0  4.845300e+10    High Cholesterol
#
# [5 rows x 25 columns]

# %%
df_austin = df_austin.drop(
    columns=[
        "DataSource",
        "Data_Value_Footnote_Symbol",
        "Data_Value_Footnote",
        "CategoryID",
        "Short_Question_Text",
        "Data_Value_Unit",
        "DataValueTypeID",
        "Data_Value_Type",
        "Low_Confidence_Limit",
        "High_Confidence_Limit",
        "CityFIPS",
        "PopulationCount",
    ]
)

# %%
df_austin = df_austin[df_austin["GeographicLevel"] == "Census Tract"]
df_austin["TractFIPS"] = df_austin["TractFIPS"].astype("int").round()

# %%
df_austin[["Lat", "Lng"]] = df_austin.GeoLocation.apply(
    lambda x: pd.Series(str(x).split(","))
)
df_austin
# Out:
#        Year StateAbbr StateDesc CityName GeographicLevel         Category  \
# 24158  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 24160  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 24161  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 24162  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 24163  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# ...     ...       ...       ...      ...             ...              ...
# 24628  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 24629  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 24630  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 24632  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 24635  2017        TX     Texas   Austin    Census Tract  Health Outcomes
#
#                   UniqueID                                            Measure  \
# 24158  4805000-48453001842  High cholesterol among adults aged >=18 Years ...
# 24160  4805000-48453001501  High cholesterol among adults aged >=18 Years ...
# 24161  4805000-48453002425  High cholesterol among adults aged >=18 Years ...
# 24162  4805000-48453001754  High cholesterol among adults aged >=18 Years ...
# 24163  4805000-48453002402  High cholesterol among adults aged >=18 Years ...
# ...                    ...                                                ...
# 24628  4805000-48453002423  High cholesterol among adults aged >=18 Years ...
# 24629  4805000-48453002308  High cholesterol among adults aged >=18 Years ...
# 24630  4805000-48453001856  High cholesterol among adults aged >=18 Years ...
# 24632  4805000-48453001901  High cholesterol among adults aged >=18 Years ...
# 24635  4805000-48453001747  High cholesterol among adults aged >=18 Years ...
#
#        Data_Value                      GeoLocation MeasureId    TractFIPS  \
# 24158        25.1  (30.3755684675, -97.6313378757)  HIGHCHOL  48453001842
# 24160        32.7  (30.3465767365, -97.7433025334)  HIGHCHOL  48453001501
# 24161        24.5   (30.157617531, -97.7842795909)  HIGHCHOL  48453002425
# 24162        30.3  (30.4065557514, -97.7373059981)  HIGHCHOL  48453001754
# 24163        25.9  (30.2016967544, -97.7751694038)  HIGHCHOL  48453002402
# ...           ...                              ...       ...          ...
# 24628        28.4  (30.1797493671, -97.8062264792)  HIGHCHOL  48453002423
# 24629        22.0   (30.229013308, -97.7521619377)  HIGHCHOL  48453002308
# 24630        29.8   (30.353335584, -97.6079431835)  HIGHCHOL  48453001856
# 24632        27.9   (30.2502692071, -97.786239289)  HIGHCHOL  48453001901
# 24635        31.1  (30.1807705165, -97.8245896819)  HIGHCHOL  48453001747
#
#                   Lat               Lng
# 24158  (30.3755684675   -97.6313378757)
# 24160  (30.3465767365   -97.7433025334)
# 24161   (30.157617531   -97.7842795909)
# 24162  (30.4065557514   -97.7373059981)
# 24163  (30.2016967544   -97.7751694038)
# ...               ...               ...
# 24628  (30.1797493671   -97.8062264792)
# 24629   (30.229013308   -97.7521619377)
# 24630   (30.353335584   -97.6079431835)
# 24632  (30.2502692071    -97.786239289)
# 24635  (30.1807705165   -97.8245896819)
#
# [205 rows x 14 columns]

# %%
df_austin[["Lat"]] = df_austin.Lat.apply(lambda x: pd.Series(x[1:]))
df_austin[["Lng"]] = df_austin.Lng.apply(lambda x: pd.Series(x[:-1]))

df_austin.to_csv("../Data/cleaned_cholesterol_cdc.csv", index=False)
df_austin
# Out:
#        Year StateAbbr StateDesc CityName GeographicLevel         Category  \
# 24158  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 24160  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 24161  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 24162  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 24163  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# ...     ...       ...       ...      ...             ...              ...
# 24628  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 24629  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 24630  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 24632  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 24635  2017        TX     Texas   Austin    Census Tract  Health Outcomes
#
#                   UniqueID                                            Measure  \
# 24158  4805000-48453001842  High cholesterol among adults aged >=18 Years ...
# 24160  4805000-48453001501  High cholesterol among adults aged >=18 Years ...
# 24161  4805000-48453002425  High cholesterol among adults aged >=18 Years ...
# 24162  4805000-48453001754  High cholesterol among adults aged >=18 Years ...
# 24163  4805000-48453002402  High cholesterol among adults aged >=18 Years ...
# ...                    ...                                                ...
# 24628  4805000-48453002423  High cholesterol among adults aged >=18 Years ...
# 24629  4805000-48453002308  High cholesterol among adults aged >=18 Years ...
# 24630  4805000-48453001856  High cholesterol among adults aged >=18 Years ...
# 24632  4805000-48453001901  High cholesterol among adults aged >=18 Years ...
# 24635  4805000-48453001747  High cholesterol among adults aged >=18 Years ...
#
#        Data_Value                      GeoLocation MeasureId    TractFIPS  \
# 24158        25.1  (30.3755684675, -97.6313378757)  HIGHCHOL  48453001842
# 24160        32.7  (30.3465767365, -97.7433025334)  HIGHCHOL  48453001501
# 24161        24.5   (30.157617531, -97.7842795909)  HIGHCHOL  48453002425
# 24162        30.3  (30.4065557514, -97.7373059981)  HIGHCHOL  48453001754
# 24163        25.9  (30.2016967544, -97.7751694038)  HIGHCHOL  48453002402
# ...           ...                              ...       ...          ...
# 24628        28.4  (30.1797493671, -97.8062264792)  HIGHCHOL  48453002423
# 24629        22.0   (30.229013308, -97.7521619377)  HIGHCHOL  48453002308
# 24630        29.8   (30.353335584, -97.6079431835)  HIGHCHOL  48453001856
# 24632        27.9   (30.2502692071, -97.786239289)  HIGHCHOL  48453001901
# 24635        31.1  (30.1807705165, -97.8245896819)  HIGHCHOL  48453001747
#
#                  Lat              Lng
# 24158  30.3755684675   -97.6313378757
# 24160  30.3465767365   -97.7433025334
# 24161   30.157617531   -97.7842795909
# 24162  30.4065557514   -97.7373059981
# 24163  30.2016967544   -97.7751694038
# ...              ...              ...
# 24628  30.1797493671   -97.8062264792
# 24629   30.229013308   -97.7521619377
# 24630   30.353335584   -97.6079431835
# 24632  30.2502692071    -97.786239289
# 24635  30.1807705165   -97.8245896819
#
# [205 rows x 14 columns]
