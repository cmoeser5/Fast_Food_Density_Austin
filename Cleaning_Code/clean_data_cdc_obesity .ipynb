# %%
# %load_ext lab_black
import pandas as pd

# %%
file_to_load = "../Data/500_Cities__Obesity_among_adults_aged___18_years.csv"

df = pd.read_csv(file_to_load)
df.head()
# Out:
#    Year StateAbbr StateDesc     CityName GeographicLevel DataSource  \
# 0  2017        HI    Hawaii     Honolulu    Census Tract      BRFSS
# 1  2017        HI    Hawaii     Honolulu    Census Tract      BRFSS
# 2  2017        GA   Georgia      Roswell            City      BRFSS
# 3  2017        HI    Hawaii     Honolulu    Census Tract      BRFSS
# 4  2017        GA   Georgia  Johns Creek    Census Tract      BRFSS
#
#               Category             UniqueID  \
# 0  Unhealthy Behaviors          15003004600
# 1  Unhealthy Behaviors          15003001400
# 2  Unhealthy Behaviors              1367284
# 3  Unhealthy Behaviors          15003010801
# 4  Unhealthy Behaviors  1342425-13121011425
#
#                                 Measure Data_Value_Unit  ...  \
# 0  Obesity among adults aged >=18 Years               %  ...
# 1  Obesity among adults aged >=18 Years               %  ...
# 2  Obesity among adults aged >=18 Years               %  ...
# 3  Obesity among adults aged >=18 Years               %  ...
# 4  Obesity among adults aged >=18 Years               %  ...
#
#   High_Confidence_Limit Data_Value_Footnote_Symbol  Data_Value_Footnote  \
# 0                  18.0                        NaN                  NaN
# 1                  19.7                        NaN                  NaN
# 2                  23.9                        NaN                  NaN
# 3                  25.0                        NaN                  NaN
# 4                  21.9                        NaN                  NaN
#
#    PopulationCount                      GeoLocation CategoryID MeasureId  \
# 0            3,735  (21.3510749539, -157.825340793)     UNHBEH   OBESITY
# 1            2,550  (21.2772209725, -157.806213514)     UNHBEH   OBESITY
# 2           88,346  (34.0391384583, -84.3512225277)     UNHBEH   OBESITY
# 3            2,969  (21.4491051468, -157.761542724)     UNHBEH   OBESITY
# 4            6,906   (34.013011213, -84.2405514785)     UNHBEH   OBESITY
#
#     CityFIPS     TractFIPS Short_Question_Text
# 0    15003.0  1.500300e+10             Obesity
# 1    15003.0  1.500300e+10             Obesity
# 2  1367284.0           NaN             Obesity
# 3    15003.0  1.500301e+10             Obesity
# 4  1342425.0  1.312101e+10             Obesity
#
# [5 rows x 24 columns]

# %%
df_austin = df[df["CityName"] == "Austin"]
df_austin.reset_index().head()
# Out:
#    index  Year StateAbbr StateDesc CityName GeographicLevel DataSource  \
# 0   2570  2017        TX     Texas   Austin    Census Tract      BRFSS
# 1  13848  2017        TX     Texas   Austin            City      BRFSS
# 2  24178  2017        TX     Texas   Austin    Census Tract      BRFSS
# 3  24179  2017        TX     Texas   Austin    Census Tract      BRFSS
# 4  24183  2017        TX     Texas   Austin    Census Tract      BRFSS
#
#               Category             UniqueID  \
# 0  Unhealthy Behaviors  4805000-48453001756
# 1  Unhealthy Behaviors              4805000
# 2  Unhealthy Behaviors  4805000-48453002212
# 3  Unhealthy Behaviors  4805000-48453001915
# 4  Unhealthy Behaviors  4805000-48491020510
#
#                                 Measure  ... High_Confidence_Limit  \
# 0  Obesity among adults aged >=18 Years  ...                  23.4
# 1  Obesity among adults aged >=18 Years  ...                  25.8
# 2  Obesity among adults aged >=18 Years  ...                  33.2
# 3  Obesity among adults aged >=18 Years  ...                  24.1
# 4  Obesity among adults aged >=18 Years  ...                  25.9
#
#   Data_Value_Footnote_Symbol Data_Value_Footnote  PopulationCount  \
# 0                        NaN                 NaN            3,997
# 1                        NaN                 NaN          790,390
# 2                        NaN                 NaN              331
# 3                        NaN                 NaN            1,439
# 4                        NaN                 NaN            3,555
#
#                        GeoLocation  CategoryID MeasureId   CityFIPS  \
# 0  (30.4261408587, -97.7697726347)      UNHBEH   OBESITY  4805000.0
# 1  (30.3068610342, -97.7554771245)      UNHBEH   OBESITY  4805000.0
# 2  (30.3101329564, -97.5916015422)      UNHBEH   OBESITY  4805000.0
# 3    (30.2407457634, -97.83861472)      UNHBEH   OBESITY  4805000.0
# 4  (30.4935333283, -97.7625330584)      UNHBEH   OBESITY  4805000.0
#
#       TractFIPS Short_Question_Text
# 0  4.845300e+10             Obesity
# 1           NaN             Obesity
# 2  4.845300e+10             Obesity
# 3  4.845300e+10             Obesity
# 4  4.849102e+10             Obesity
#
# [5 rows x 25 columns]

# %%
df_austin = df_austin.drop(
    columns=[
        "DataSource",
        "Data_Value_Footnote_Symbol",
        "Data_Value_Footnote",
        "CategoryID",
        "Short_Question_Text",
        "Data_Value_Unit",
        "DataValueTypeID",
        "Data_Value_Type",
        "Data_Value",
        "Low_Confidence_Limit",
        "High_Confidence_Limit",
        "CityFIPS",
    ]
)

# %%
df_austin = df_austin[df_austin["GeographicLevel"] == "Census Tract"]
df_austin["TractFIPS"] = df_austin["TractFIPS"].astype("int").round()

# %%
df_austin[["Lat", "Lng"]] = df_austin.GeoLocation.apply(
    lambda x: pd.Series(str(x).split(","))
)
df_austin
# Out:
#        Year StateAbbr StateDesc CityName GeographicLevel             Category  \
# 2570   2017        TX     Texas   Austin    Census Tract  Unhealthy Behaviors
# 24178  2017        TX     Texas   Austin    Census Tract  Unhealthy Behaviors
# 24179  2017        TX     Texas   Austin    Census Tract  Unhealthy Behaviors
# 24183  2017        TX     Texas   Austin    Census Tract  Unhealthy Behaviors
# 24185  2017        TX     Texas   Austin    Census Tract  Unhealthy Behaviors
# ...     ...       ...       ...      ...             ...                  ...
# 24642  2017        TX     Texas   Austin    Census Tract  Unhealthy Behaviors
# 24643  2017        TX     Texas   Austin    Census Tract  Unhealthy Behaviors
# 24645  2017        TX     Texas   Austin    Census Tract  Unhealthy Behaviors
# 24648  2017        TX     Texas   Austin    Census Tract  Unhealthy Behaviors
# 24652  2017        TX     Texas   Austin    Census Tract  Unhealthy Behaviors
#
#                   UniqueID                               Measure  \
# 2570   4805000-48453001756  Obesity among adults aged >=18 Years
# 24178  4805000-48453002212  Obesity among adults aged >=18 Years
# 24179  4805000-48453001915  Obesity among adults aged >=18 Years
# 24183  4805000-48491020510  Obesity among adults aged >=18 Years
# 24185  4805000-48453002107  Obesity among adults aged >=18 Years
# ...                    ...                                   ...
# 24642  4805000-48453000402  Obesity among adults aged >=18 Years
# 24643  4805000-48453002313  Obesity among adults aged >=18 Years
# 24645  4805000-48453002428  Obesity among adults aged >=18 Years
# 24648  4805000-48453001842  Obesity among adults aged >=18 Years
# 24652  4805000-48491020316  Obesity among adults aged >=18 Years
#
#       PopulationCount                      GeoLocation MeasureId    TractFIPS  \
# 2570            3,997  (30.4261408587, -97.7697726347)   OBESITY  48453001756
# 24178             331  (30.3101329564, -97.5916015422)   OBESITY  48453002212
# 24179           1,439    (30.2407457634, -97.83861472)   OBESITY  48453001915
# 24183           3,555  (30.4935333283, -97.7625330584)   OBESITY  48491020510
# 24185           3,712  (30.2956745244, -97.6828566374)   OBESITY  48453002107
# ...               ...                              ...       ...          ...
# 24642           2,606  (30.2841414645, -97.7155188107)   OBESITY  48453000402
# 24643           4,311  (30.2201787759, -97.7259170867)   OBESITY  48453002313
# 24645           4,323  (30.1388923291, -97.7817189485)   OBESITY  48453002428
# 24648           2,035  (30.3755684675, -97.6313378757)   OBESITY  48453001842
# 24652              30  (30.4767287286, -97.8094310538)   OBESITY  48491020316
#
#                   Lat               Lng
# 2570   (30.4261408587   -97.7697726347)
# 24178  (30.3101329564   -97.5916015422)
# 24179  (30.2407457634     -97.83861472)
# 24183  (30.4935333283   -97.7625330584)
# 24185  (30.2956745244   -97.6828566374)
# ...               ...               ...
# 24642  (30.2841414645   -97.7155188107)
# 24643  (30.2201787759   -97.7259170867)
# 24645  (30.1388923291   -97.7817189485)
# 24648  (30.3755684675   -97.6313378757)
# 24652  (30.4767287286   -97.8094310538)
#
# [205 rows x 14 columns]

# %%
df_austin[["Lat"]] = df_austin.Lat.apply(lambda x: pd.Series(x[1:]))
df_austin[["Lng"]] = df_austin.Lng.apply(lambda x: pd.Series(x[:-1]))

df_austin.to_csv("../Data/cleaned_obesity_cdc.csv")
