# %%
# %load_ext lab_black
import pandas as pd

# %%
file_to_load = "../Data/500_Cities__Diagnosed_diabetes_among_adults_aged___18_years.csv"

df = pd.read_csv(file_to_load)
df.head()
# Out:
#    Year StateAbbr StateDesc    CityName GeographicLevel DataSource  \
# 0  2017        ID     Idaho       Nampa    Census Tract      BRFSS
# 1  2017        GA   Georgia    Columbus    Census Tract      BRFSS
# 2  2017        ID     Idaho  Boise City    Census Tract      BRFSS
# 3  2017        HI    Hawaii    Honolulu    Census Tract      BRFSS
# 4  2017        GA   Georgia       Macon    Census Tract      BRFSS
#
#           Category             UniqueID  \
# 0  Health Outcomes  1656260-16027020601
# 1  Health Outcomes  1319000-13215001800
# 2  Health Outcomes  1608830-16001001000
# 3  Health Outcomes          15003003403
# 4  Health Outcomes  1349000-13021013202
#
#                                            Measure Data_Value_Unit  ...  \
# 0  Diagnosed diabetes among adults aged >=18 Years               %  ...
# 1  Diagnosed diabetes among adults aged >=18 Years               %  ...
# 2  Diagnosed diabetes among adults aged >=18 Years               %  ...
# 3  Diagnosed diabetes among adults aged >=18 Years               %  ...
# 4  Diagnosed diabetes among adults aged >=18 Years               %  ...
#
#   High_Confidence_Limit Data_Value_Footnote_Symbol  Data_Value_Footnote  \
# 0                   8.8                        NaN                  NaN
# 1                  17.2                        NaN                  NaN
# 2                   7.8                        NaN                  NaN
# 3                  12.2                        NaN                  NaN
# 4                  18.4                        NaN                  NaN
#
#    PopulationCount                      GeoLocation CategoryID MeasureId  \
# 0            4,707  (43.5833173278, -116.602873996)    HLTHOUT  DIABETES
# 1            1,272  (32.4768765352, -84.9758274687)    HLTHOUT  DIABETES
# 2            5,997  (43.6087482229, -116.228075339)    HLTHOUT  DIABETES
# 3            5,530  (21.3072907725, -157.844275604)    HLTHOUT  DIABETES
# 4            2,952  (32.8084122826, -83.7042441207)    HLTHOUT  DIABETES
#
#     CityFIPS     TractFIPS Short_Question_Text
# 0  1656260.0  1.602702e+10            Diabetes
# 1  1319000.0  1.321500e+10            Diabetes
# 2  1608830.0  1.600100e+10            Diabetes
# 3    15003.0  1.500300e+10            Diabetes
# 4  1349000.0  1.302101e+10            Diabetes
#
# [5 rows x 24 columns]

# %%
df_austin = df[df["CityName"] == "Austin"]
df_austin.reset_index().head()
# Out:
#    index  Year StateAbbr StateDesc CityName GeographicLevel DataSource  \
# 0  24168  2017        TX     Texas   Austin    Census Tract      BRFSS
# 1  24170  2017        TX     Texas   Austin    Census Tract      BRFSS
# 2  24176  2017        TX     Texas   Austin    Census Tract      BRFSS
# 3  24177  2017        TX     Texas   Austin            City      BRFSS
# 4  24178  2017        TX     Texas   Austin    Census Tract      BRFSS
#
#           Category             UniqueID  \
# 0  Health Outcomes  4805000-48453001911
# 1  Health Outcomes  4805000-48453001835
# 2  Health Outcomes  4805000-48453001811
# 3  Health Outcomes              4805000
# 4  Health Outcomes  4805000-48453001738
#
#                                            Measure  ... High_Confidence_Limit  \
# 0  Diagnosed diabetes among adults aged >=18 Years  ...                   3.8
# 1  Diagnosed diabetes among adults aged >=18 Years  ...                   8.7
# 2  Diagnosed diabetes among adults aged >=18 Years  ...                  12.2
# 3  Diagnosed diabetes among adults aged >=18 Years  ...                   9.8
# 4  Diagnosed diabetes among adults aged >=18 Years  ...                   8.1
#
#   Data_Value_Footnote_Symbol Data_Value_Footnote  PopulationCount  \
# 0                        NaN                 NaN            2,825
# 1                        NaN                 NaN            5,000
# 2                        NaN                 NaN            3,546
# 3                        NaN                 NaN          790,390
# 4                        NaN                 NaN            6,647
#
#                        GeoLocation  CategoryID MeasureId   CityFIPS  \
# 0  (30.2584881046, -97.7858836263)     HLTHOUT  DIABETES  4805000.0
# 1   (30.3868001522, -97.661485146)     HLTHOUT  DIABETES  4805000.0
# 2  (30.3261510878, -97.6850226617)     HLTHOUT  DIABETES  4805000.0
# 3  (30.3068610342, -97.7554771245)     HLTHOUT  DIABETES  4805000.0
# 4   (30.2186732803, -97.859799421)     HLTHOUT  DIABETES  4805000.0
#
#       TractFIPS Short_Question_Text
# 0  4.845300e+10            Diabetes
# 1  4.845300e+10            Diabetes
# 2  4.845300e+10            Diabetes
# 3           NaN            Diabetes
# 4  4.845300e+10            Diabetes
#
# [5 rows x 25 columns]

# %%
df_austin = df_austin.drop(
    columns=[
        "DataSource",
        "Data_Value_Footnote_Symbol",
        "Data_Value_Footnote",
        "CategoryID",
        "Short_Question_Text",
        "Data_Value_Unit",
        "DataValueTypeID",
        "Data_Value_Type",
        "Low_Confidence_Limit",
        "High_Confidence_Limit",
        "CityFIPS",
        "PopulationCount",
    ]
)

# %%
df_austin = df_austin[df_austin["GeographicLevel"] == "Census Tract"]
df_austin["TractFIPS"] = df_austin["TractFIPS"].astype("int").round()

# %%
df_austin[["Lat", "Lng"]] = df_austin.GeoLocation.apply(
    lambda x: pd.Series(str(x).split(","))
)
df_austin
# Out:
#        Year StateAbbr StateDesc CityName GeographicLevel         Category  \
# 24168  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 24170  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 24176  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 24178  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 24180  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# ...     ...       ...       ...      ...             ...              ...
# 24633  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 24635  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 24638  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 24641  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 24643  2017        TX     Texas   Austin    Census Tract  Health Outcomes
#
#                   UniqueID                                          Measure  \
# 24168  4805000-48453001911  Diagnosed diabetes among adults aged >=18 Years
# 24170  4805000-48453001835  Diagnosed diabetes among adults aged >=18 Years
# 24176  4805000-48453001811  Diagnosed diabetes among adults aged >=18 Years
# 24178  4805000-48453001738  Diagnosed diabetes among adults aged >=18 Years
# 24180  4805000-48453001605  Diagnosed diabetes among adults aged >=18 Years
# ...                    ...                                              ...
# 24633  4805000-48453002005  Diagnosed diabetes among adults aged >=18 Years
# 24635  4805000-48453001746  Diagnosed diabetes among adults aged >=18 Years
# 24638  4805000-48453002433  Diagnosed diabetes among adults aged >=18 Years
# 24641  4805000-48453001842  Diagnosed diabetes among adults aged >=18 Years
# 24643  4805000-48453002211  Diagnosed diabetes among adults aged >=18 Years
#
#        Data_Value                      GeoLocation MeasureId    TractFIPS  \
# 24168         3.5  (30.2584881046, -97.7858836263)  DIABETES  48453001911
# 24170         8.3   (30.3868001522, -97.661485146)  DIABETES  48453001835
# 24176        11.5  (30.3261510878, -97.6850226617)  DIABETES  48453001811
# 24178         7.6   (30.2186732803, -97.859799421)  DIABETES  48453001738
# 24180         5.3  (30.2867724621, -97.7605749891)  DIABETES  48453001605
# ...           ...                              ...       ...          ...
# 24633         6.9  (30.2348343932, -97.7801522706)  DIABETES  48453002005
# 24635         7.2   (30.1860608718, -97.838251775)  DIABETES  48453001746
# 24638         9.4  (30.1912019968, -97.6172300469)  DIABETES  48453002433
# 24641         7.7  (30.3755684675, -97.6313378757)  DIABETES  48453001842
# 24643         8.5  (30.2775754938, -97.6282935126)  DIABETES  48453002211
#
#                   Lat               Lng
# 24168  (30.2584881046   -97.7858836263)
# 24170  (30.3868001522    -97.661485146)
# 24176  (30.3261510878   -97.6850226617)
# 24178  (30.2186732803    -97.859799421)
# 24180  (30.2867724621   -97.7605749891)
# ...               ...               ...
# 24633  (30.2348343932   -97.7801522706)
# 24635  (30.1860608718    -97.838251775)
# 24638  (30.1912019968   -97.6172300469)
# 24641  (30.3755684675   -97.6313378757)
# 24643  (30.2775754938   -97.6282935126)
#
# [205 rows x 14 columns]

# %%
df_austin[["Lat"]] = df_austin.Lat.apply(lambda x: pd.Series(x[1:]))
df_austin[["Lng"]] = df_austin.Lng.apply(lambda x: pd.Series(x[:-1]))

df_austin.to_csv("../Data/cleaned_diabetes_cdc.csv", index=False)
df_austin
# Out:
#        Year StateAbbr StateDesc CityName GeographicLevel         Category  \
# 24168  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 24170  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 24176  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 24178  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 24180  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# ...     ...       ...       ...      ...             ...              ...
# 24633  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 24635  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 24638  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 24641  2017        TX     Texas   Austin    Census Tract  Health Outcomes
# 24643  2017        TX     Texas   Austin    Census Tract  Health Outcomes
#
#                   UniqueID                                          Measure  \
# 24168  4805000-48453001911  Diagnosed diabetes among adults aged >=18 Years
# 24170  4805000-48453001835  Diagnosed diabetes among adults aged >=18 Years
# 24176  4805000-48453001811  Diagnosed diabetes among adults aged >=18 Years
# 24178  4805000-48453001738  Diagnosed diabetes among adults aged >=18 Years
# 24180  4805000-48453001605  Diagnosed diabetes among adults aged >=18 Years
# ...                    ...                                              ...
# 24633  4805000-48453002005  Diagnosed diabetes among adults aged >=18 Years
# 24635  4805000-48453001746  Diagnosed diabetes among adults aged >=18 Years
# 24638  4805000-48453002433  Diagnosed diabetes among adults aged >=18 Years
# 24641  4805000-48453001842  Diagnosed diabetes among adults aged >=18 Years
# 24643  4805000-48453002211  Diagnosed diabetes among adults aged >=18 Years
#
#        Data_Value                      GeoLocation MeasureId    TractFIPS  \
# 24168         3.5  (30.2584881046, -97.7858836263)  DIABETES  48453001911
# 24170         8.3   (30.3868001522, -97.661485146)  DIABETES  48453001835
# 24176        11.5  (30.3261510878, -97.6850226617)  DIABETES  48453001811
# 24178         7.6   (30.2186732803, -97.859799421)  DIABETES  48453001738
# 24180         5.3  (30.2867724621, -97.7605749891)  DIABETES  48453001605
# ...           ...                              ...       ...          ...
# 24633         6.9  (30.2348343932, -97.7801522706)  DIABETES  48453002005
# 24635         7.2   (30.1860608718, -97.838251775)  DIABETES  48453001746
# 24638         9.4  (30.1912019968, -97.6172300469)  DIABETES  48453002433
# 24641         7.7  (30.3755684675, -97.6313378757)  DIABETES  48453001842
# 24643         8.5  (30.2775754938, -97.6282935126)  DIABETES  48453002211
#
#                  Lat              Lng
# 24168  30.2584881046   -97.7858836263
# 24170  30.3868001522    -97.661485146
# 24176  30.3261510878   -97.6850226617
# 24178  30.2186732803    -97.859799421
# 24180  30.2867724621   -97.7605749891
# ...              ...              ...
# 24633  30.2348343932   -97.7801522706
# 24635  30.1860608718    -97.838251775
# 24638  30.1912019968   -97.6172300469
# 24641  30.3755684675   -97.6313378757
# 24643  30.2775754938   -97.6282935126
#
# [205 rows x 14 columns]
